# %% [markdown]
# <a href="https://colab.research.google.com/github/ai-ellie/github_beginner/blob/main/%EC%8B%AC%ED%99%946_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pandas import 하기
import pandas as pd

# %% [markdown]
# # Series 생성

# %% [markdown]
# ## 리스트로 생성

# %%
animals = ['Tiger','Bears','Moose']
s1 = pd.Series(animals)
s1
# Out:
# 0    Tiger
# 1    Bears
# 2    Moose
# dtype: object

# %%
numbers = [1,2,3]
s2 = pd.Series(numbers)
s2
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %% [markdown]
# ## 딕셔너리로 생성

# %%
dic = {'a':1, 'b':2,'C':3}
s3 = pd.Series(dic)
s3
# Out:
# a    1
# b    2
# C    3
# dtype: int64

# %% [markdown]
# # DaraFrame 생성

# %%
#numpy 배열로 생성
import numpy as np

arr = np.array([[1,2,3],[4,5,6]])
pd.DataFrame(arr)
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6

# %%
#딕셔너리로 생성
dic = {'a':[1,3],'b':[1,2],'c':[2,4]}
pd.DataFrame(dic)
# Out:
#    a  b  c
# 0  1  1  2
# 1  3  2  4

# %%
#DataFrame()함수로 생성
df1 = pd.DataFrame(data=[4,5,6,7], index=range(0,4),columns =['A'])
df1
# Out:
#    A
# 0  4
# 1  5
# 2  6
# 3  7

# %%
#시리즈로 생성
s1 = pd.Series({'UK':'London','India':'NewDelhi','US':'Washington'})
pd.DataFrame(s1)
# Out:
#                 0
# UK         London
# India    NewDelhi
# US     Washington

# %% [markdown]
# # DataFrame 행과 열 **다루기**

# %%
#행과 열이름 보기

df = pd.DataFrame([[2,'남','컴퓨터공학과'],[3,'여','수학과'],[1,'남','정보통신공학과']],index=['재석','수지','정재'],columns=['학년','성별','학교'])
df
# Out:
#     학년 성별       학교
# 재석   2  남   컴퓨터공학과
# 수지   3  여      수학과
# 정재   1  남  정보통신공학과

# %%
df.index
# Out:
# Index(['재석', '수지', '정재'], dtype='object')

# %%
df.columns
# Out:
# Index(['학년', '성별', '학교'], dtype='object')

# %%
#행과 열이름 바꾸기

exam =  {'수학':[90,80,70],'영어':[98,89,95],'음악':[85,95,100],'체육':[100,90,90]}
df = pd.DataFrame(exam, index=['택','정환','덕선'])
df
# Out:
#     수학  영어   음악   체육
# 택   90  98   85  100
# 정환  80  89   95   90
# 덕선  70  95  100   90

# %%
df.index = ['택','환','선']
df
# Out:
#    수학  영어   음악   체육
# 택  90  98   85  100
# 환  80  89   95   90
# 선  70  95  100   90

# %%
df.columns = ['수','영','음','체']
df
# Out:
#     수   영    음    체
# 택  90  98   85  100
# 환  80  89   95   90
# 선  70  95  100   90

# %%
#행과 열이름 일부만 바꾸기

df.rename(index = {'택':'최택'})
# Out:
#      수   영    음    체
# 최택  90  98   85  100
# 환   80  89   95   90
# 선   70  95  100   90

# %%
df.rename(columns= {"수학":"Math",'영어':'English'},inplace= True)
df
# Out:
#     수   영    음    체
# 택  90  98   85  100
# 환  80  89   95   90
# 선  70  95  100   90

# %%
# 행 추가하기
df.loc['선우'] = [95,100,80,95]
df
# Out:
#      수    영    음    체
# 택   90   98   85  100
# 환   80   89   95   90
# 선   70   95  100   90
# 선우  95  100   80   95

# %%
#열 추가하기
df['국어'] = [80,90,95,100]
df
# Out:
#      수    영    음    체   국어
# 택   90   98   85  100   80
# 환   80   89   95   90   90
# 선   70   95  100   90   95
# 선우  95  100   80   95  100

# %%
df['과학']=80
df
# Out:
#      수    영    음    체   국어  과학
# 택   90   98   85  100   80  80
# 환   80   89   95   90   90  80
# 선   70   95  100   90   95  80
# 선우  95  100   80   95  100  80

# %%
#행 삭제하기
df.drop(['택','선'])
# Out:
#      수    영   음   체   국어  과학
# 환   80   89  95  90   90  80
# 선우  95  100  80  95  100  80

# %%
df
# Out:
#      수    영    음    체   국어  과학
# 택   90   98   85  100   80  80
# 환   80   89   95   90   90  80
# 선   70   95  100   90   95  80
# 선우  95  100   80   95  100  80

# %%
df.drop(['택','선'], inplace = True)

# %%
df
# Out:
#      수    영   음   체   국어  과학
# 환   80   89  95  90   90  80
# 선우  95  100  80  95  100  80

# %%
#열 삭제하기
df.drop('체',axis =1)
# Out:
#      수    영   음   국어  과학
# 환   80   89  95   90  80
# 선우  95  100  80  100  80

# %%
exam =  {'수학':[90,80,70],'영어':[98,89,95],'음악':[85,95,100],'체육':[100,90,90]}
df = pd.DataFrame(exam, index=['택','정환','덕선'])
df
# Out:
#     수학  영어   음악   체육
# 택   90  98   85  100
# 정환  80  89   95   90
# 덕선  70  95  100   90

# %%
#행 선택하기
df.loc['덕선']
# Out:
# 수학     70
# 영어     95
# 음악    100
# 체육     90
# Name: 덕선, dtype: int64

# %%
df.loc[['택','정환']]
# Out:
#     수학  영어  음악   체육
# 택   90  98  85  100
# 정환  80  89  95   90

# %%
df.iloc[0]
# Out:
# 수학     90
# 영어     98
# 음악     85
# 체육    100
# Name: 택, dtype: int64

# %%
df.iloc[0:2]
# Out:
#     수학  영어  음악   체육
# 택   90  98  85  100
# 정환  80  89  95   90

# %%
#열 선택하기

df[['수학']]
# Out:
#     수학
# 택   90
# 정환  80
# 덕선  70

# %%
df[['음악','수학']]
# Out:
#      음악  수학
# 택    85  90
# 정환   95  80
# 덕선  100  70

# %%
df.수학
# Out:
# 택     90
# 정환    80
# 덕선    70
# Name: 수학, dtype: int64

# %%
# 행 추가하기
df.loc['선우'] = [95,100,80,95]
df
# Out:
#     수학   영어   음악   체육
# 택   90   98   85  100
# 정환  80   89   95   90
# 덕선  70   95  100   90
# 선우  95  100   80   95

# %%
#원소 조회하기
df.head(2)
# Out:
#     수학  영어  음악   체육
# 택   90  98  85  100
# 정환  80  89  95   90

# %%
df.tail(2)
# Out:
#     수학   영어   음악  체육
# 덕선  70   95  100  90
# 선우  95  100   80  95

# %%
df[1:3]
# Out:
#     수학  영어   음악  체육
# 정환  80  89   95  90
# 덕선  70  95  100  90

# %%
df.loc[['택','선우']]
# Out:
#     수학   영어  음악   체육
# 택   90   98  85  100
# 선우  95  100  80   95

# %%
df.loc['덕선','음악']
# Out:
# 100

# %%
df.iloc[2,3]
# Out:
# 90

# %%
df.iloc[2][3]
# Out:
# 90

# %%
#원소 값 바꾸기
df
# Out:
#     수학   영어   음악   체육
# 택   90   98   85  100
# 정환  80   89   95   90
# 덕선  70   95  100   90
# 선우  95  100   80   95

# %%
df.loc['택','수학']=100
df
# Out:
#      수학   영어   음악   체육
# 택   100   98   85  100
# 정환   80   89   95   90
# 덕선   70   95  100   90
# 선우   95  100   80   95

# %%
df.iloc[2,3] = 95
df
# Out:
#      수학   영어   음악   체육
# 택   100   98   85  100
# 정환   80   89   95   90
# 덕선   70   95  100   95
# 선우   95  100   80   95

# %%
df.loc['덕선',['수학','영어']] = 80,100
df
# Out:
#      수학   영어   음악   체육
# 택   100   98   85  100
# 정환   80   89   95   90
# 덕선   80  100  100   95
# 선우   95  100   80   95

# %% [markdown]
# # CSV 파일 다루기

# %%
import pandas as pd

path = 'https://github.com/dongupak/DataML/raw/main/csv/'
file = path+'vehicle_prod.csv'
df = pd.read_csv(file)   # 원격지에 접속하여 csv를 읽어옴
df
# Out:
#   Unnamed: 0   2007   2008   2009   2010   2011
# 0      China   7.71   7.95  11.96  15.84  16.33
# 1         EU  19.02  17.71  15.00  16.70  17.48
# 2         US  10.47   8.45   5.58   7.60   8.40
# 3      Japan  10.87  10.83   7.55   9.09   7.88
# 4      Korea   4.04   3.78   3.45   4.20   4.62
# 5     Mexico   2.01   2.05   1.50   2.25   2.54

# %%
#첫번째 열을 인덱스로 사용
df = pd.read_csv(file, index_col = 0)
df
# Out:
#          2007   2008   2009   2010   2011
# China    7.71   7.95  11.96  15.84  16.33
# EU      19.02  17.71  15.00  16.70  17.48
# US      10.47   8.45   5.58   7.60   8.40
# Japan   10.87  10.83   7.55   9.09   7.88
# Korea    4.04   3.78   3.45   4.20   4.62
# Mexico   2.01   2.05   1.50   2.25   2.54

# %%
df.columns
# Out:
# Index(['2007', '2008', '2009', '2010', '2011'], dtype='object')

# %%
df.index
# Out:
# Index(['China', 'EU', 'US', 'Japan', 'Korea', 'Mexico'], dtype='object')

# %%
df['2007']
# Out:
# China      7.71
# EU        19.02
# US        10.47
# Japan     10.87
# Korea      4.04
# Mexico     2.01
# Name: 2007, dtype: float64

# %%
#리스트로 반환
df.columns.tolist()
# Out:
# ['2007', '2008', '2009', '2010', '2011']

# %%
df['2007'].tolist()
# Out:
# [7.71, 19.02, 10.47, 10.87, 4.04, 2.01]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, China to Mexico
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2007    6 non-null      float64
#  1   2008    6 non-null      float64
#  2   2009    6 non-null      float64
#  3   2010    6 non-null      float64
#  4   2011    6 non-null      float64
# dtypes: float64(5)
# memory usage: 448.0+ bytes

# %%
df.describe()
# Out:
#             2007       2008       2009       2010       2011
# count   6.000000   6.000000   6.000000   6.000000   6.000000
# mean    9.020000   8.461667   7.506667   9.280000   9.541667
# std     6.019661   5.557519   5.142621   5.935921   6.105887
# min     2.010000   2.050000   1.500000   2.250000   2.540000
# 25%     4.957500   4.822500   3.982500   5.050000   5.435000
# 50%     9.090000   8.200000   6.565000   8.345000   8.140000
# 75%    10.770000  10.235000  10.857500  14.152500  14.347500
# max    19.020000  17.710000  15.000000  16.700000  17.480000

# %%
df.head()
# Out:
#         2007   2008   2009   2010   2011
# China   7.71   7.95  11.96  15.84  16.33
# EU     19.02  17.71  15.00  16.70  17.48
# US     10.47   8.45   5.58   7.60   8.40
# Japan  10.87  10.83   7.55   9.09   7.88
# Korea   4.04   3.78   3.45   4.20   4.62

# %%
df.head(2)
# Out:
#         2007   2008   2009   2010   2011
# China   7.71   7.95  11.96  15.84  16.33
# EU     19.02  17.71  15.00  16.70  17.48

# %%
df.tail()
# Out:
#          2007   2008   2009   2010   2011
# EU      19.02  17.71  15.00  16.70  17.48
# US      10.47   8.45   5.58   7.60   8.40
# Japan   10.87  10.83   7.55   9.09   7.88
# Korea    4.04   3.78   3.45   4.20   4.62
# Mexico   2.01   2.05   1.50   2.25   2.54

# %%
#자동차 총 생상대수 열 생성

df['total'] = df.sum(axis=1)
df
# Out:
#          2007   2008   2009   2010   2011   total
# China    7.71   7.95  11.96  15.84  16.33  119.58
# EU      19.02  17.71  15.00  16.70  17.48  171.82
# US      10.47   8.45   5.58   7.60   8.40   81.00
# Japan   10.87  10.83   7.55   9.09   7.88   92.44
# Korea    4.04   3.78   3.45   4.20   4.62   40.18
# Mexico   2.01   2.05   1.50   2.25   2.54   20.70

# %%
#총 샌산대수 평균 열 생성

df['mean'] = df[['2007','2008','2009','2010','2011']].mean(axis=1)
df
# Out:
#          2007   2008   2009   2010   2011   total    mean
# China    7.71   7.95  11.96  15.84  16.33  119.58  11.958
# EU      19.02  17.71  15.00  16.70  17.48  171.82  17.182
# US      10.47   8.45   5.58   7.60   8.40   81.00   8.100
# Japan   10.87  10.83   7.55   9.09   7.88   92.44   9.244
# Korea    4.04   3.78   3.45   4.20   4.62   40.18   4.018
# Mexico   2.01   2.05   1.50   2.25   2.54   20.70   2.070

# %%
#2007년 생산대수 삭제
df.drop('2007', inplace=True, axis = 1)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-d5bfd395dedd> in <module>()
#       1 #2007년 생산대수 삭제
# ----> 2 df.drop('2007', inplace=True, axis = 1)
#       3 df
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
#    3891         if inplace:
#
# ...

# %%
df.median()
# Out:
# 2008      8.200
# 2009      6.565
# 2010      8.345
# 2011      8.140
# total    86.720
# mean      8.672
# dtype: float64

# %%
df.max()
# Out:
# 2008      17.710
# 2009      15.000
# 2010      16.700
# 2011      17.480
# total    171.820
# mean      17.182
# dtype: float64

# %%
df.std()
# Out:
# 2008      5.557519
# 2009      5.142621
# 2010      5.935921
# 2011      6.105887
# total    54.602158
# mean      5.460216
# dtype: float64

# %% [markdown]
# # 실습I

# %% [markdown]
# ## 1. 국가별 자동차 생산대수 데이터셋을 가져와서 데이터프레임을 생성하고 연도별 생산대수의 합을 다음과 가팅 'total'이라는 이름의 행으로 가장 아래 행에 출력하세요(힌트: 데이터 프레임에서 국가명을 제외한 숫자의 합을 구하는 메소드로 select_dtypes(np.number).sum().rename() )

# %%
import pandas as pd
import numpy as np

# github의 자동차 생산 자료를 읽어들인다
path = 'https://github.com/dongupak/DataML/raw/main/csv/'
file = path+'vehicle_prod.csv'
df = pd.read_csv(file, index_col=0) 
# 데이터 프레임에서 국가명을 제외한 숫자의 합을 구하여 Total로 명명
sums = df.select_dtypes(np.number).sum().rename('Total')
total_df = df.append(sums)
total_df
# Out:
#          2007   2008   2009   2010   2011
# China    7.71   7.95  11.96  15.84  16.33
# EU      19.02  17.71  15.00  16.70  17.48
# US      10.47   8.45   5.58   7.60   8.40
# Japan   10.87  10.83   7.55   9.09   7.88
# Korea    4.04   3.78   3.45   4.20   4.62
# Mexico   2.01   2.05   1.50   2.25   2.54
# Total   54.12  50.77  45.04  55.68  57.25

# %% [markdown]
# ## 2. 다음의 시리즈를 사용하여 상점 월별 수익과 지출을 나타내는 DataFrame을 생성하세요.
# ```
# month_se = pd.Series(['1월', '2월', '3월', '4월'])
# income_se = pd.Series([9500, 6200, 6050, 7000])
# expenses_se = pd.Series([5040, 2350, 2300, 4800])
# ```
# ```
# 	월	수익	지출
# 0	1월	9500	5040
# 1	2월	6200	2350
# 2	3월	6050	2300
# 3	4월	7000	4800
# ```

# %%
month_se = pd.Series(['1월', '2월', '3월', '4월'])
income_se = pd.Series([9500, 6200, 6050, 7000])
expenses_se = pd.Series([5040, 2350, 2300, 4800])
df = pd.DataFrame({"월":month_se,"수익":income_se,"지출":expenses_se})
df
# Out:
#     월    수익    지출
# 0  1월  9500  5040
# 1  2월  6200  2350
# 2  3월  6050  2300
# 3  4월  7000  4800

# %% [markdown]
# ## 3. 문제 1의 DataFrame 을 이용하여 KNU 상점의 1월부터 4월가지 의 월 매출의 합과 월 지출의 합을 출력해보세요.(힌트: 쉼표 구분자를 출력하는 출력 formatter 사용)

# %%
print('상점의 수익 합계: {:,}'.format(df['수익'].sum()))
print('상점의 지출 합계: {:,}'.format(df['지출'].sum()))
# Out:
# 상점의 수익 합계: 28,750
# 상점의 지출 합계: 14,490

# %% [markdown]
# # DataFrame 시각화

# %%
path = 'https://github.com/dongupak/DataML/raw/main/csv/'
file = path+'vehicle_prod.csv'
df = pd.read_csv(file, index_col = 0)
df
# Out:
#          2007   2008   2009   2010   2011
# China    7.71   7.95  11.96  15.84  16.33
# EU      19.02  17.71  15.00  16.70  17.48
# US      10.47   8.45   5.58   7.60   8.40
# Japan   10.87  10.83   7.55   9.09   7.88
# Korea    4.04   3.78   3.45   4.20   4.62
# Mexico   2.01   2.05   1.50   2.25   2.54

# %%
df.plot.line()

# %%
df.plot.bar()

# %%
df1 = df.transpose()
df1
# Out:
#       China     EU     US  Japan  Korea  Mexico
# 2007   7.71  19.02  10.47  10.87   4.04    2.01
# 2008   7.95  17.71   8.45  10.83   3.78    2.05
# 2009  11.96  15.00   5.58   7.55   3.45    1.50
# 2010  15.84  16.70   7.60   9.09   4.20    2.25
# 2011  16.33  17.48   8.40   7.88   4.62    2.54

# %%
df1.plot.line()

# %%
df['2009'].plot(kind='bar',color=('orange','r','b','m','c','k'))

# %%
df['2009'].plot(kind='pie')

# %% [markdown]
# # 결측치 처리

# %%
from google.colab import drive 
drive.mount('/content/drive/')

file = '/content/drive/My Drive/Colab Notebooks/titanic.csv'

df = pd.read_csv(file)
df.head()
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#결측치 조회

df.isnull() #df.isna() 같음
# Out:
#      PassengerId  Survived  Pclass   Name  ...  Ticket   Fare  Cabin  Embarked
# 0          False     False   False  False  ...   False  False   True     False
# 1          False     False   False  False  ...   False  False  False     False
# 2          False     False   False  False  ...   False  False   True     False
# 3          False     False   False  False  ...   False  False  False     False
# 4          False     False   False  False  ...   False  False   True     False
# ..           ...       ...     ...    ...  ...     ...    ...    ...       ...
# 886        False     False   False  False  ...   False  False   True     False
# 887        False     False   False  False  ...   False  False  False     False
# 888        False     False   False  False  ...   False  False   True     False
# 889        False     False   False  False  ...   False  False  False     False
# 890        False     False   False  False  ...   False  False   True     False
#
# [891 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#행 삭제
df.dropna()
# Out:
#      PassengerId  Survived  Pclass  ...     Fare        Cabin  Embarked
# 1              2         1       1  ...  71.2833          C85         C
# 3              4         1       1  ...  53.1000         C123         S
# 6              7         0       1  ...  51.8625          E46         S
# 10            11         1       3  ...  16.7000           G6         S
# 11            12         1       1  ...  26.5500         C103         S
# ..           ...       ...     ...  ...      ...          ...       ...
# 871          872         1       1  ...  52.5542          D35         S
# 872          873         0       1  ...   5.0000  B51 B53 B55         S
# 879          880         1       1  ...  83.1583          C50         C
# 887          888         1       1  ...  30.0000          B42         S
# 889          890         1       1  ...  30.0000         C148         C
#
# [183 rows x 12 columns]

# %%
df.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.count()
# Out:
# PassengerId    183
# Survived       183
# Pclass         183
# Name           183
# Sex            183
# Age            183
# SibSp          183
# Parch          183
# Ticket         183
# Fare           183
# Cabin          183
# Embarked       183
# dtype: int64

# %%
#열 삭제
from google.colab import drive 
drive.mount('/content/drive/')

file = '/content/drive/My Drive/Colab Notebooks/titanic.csv'

df = pd.read_csv(file)
df.dropna(axis=1, inplace=True)
df
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
#      PassengerId  Survived  Pclass  ... Parch            Ticket     Fare
# 0              1         0       3  ...     0         A/5 21171   7.2500
# 1              2         1       1  ...     0          PC 17599  71.2833
# 2              3         1       3  ...     0  STON/O2. 3101282   7.9250
# 3              4         1       1  ...     0            113803  53.1000
# 4              5         0       3  ...     0            373450   8.0500
# ..           ...       ...     ...  ...   ...               ...      ...
# 886          887         0       2  ...     0            211536  13.0000
# 887          888         1       1  ...     0            112053  30.0000
# 888          889         0       3  ...     2        W./C. 6607  23.4500
# 889          890         1       1  ...     0            111369  30.0000
# ...

# %%
#평균값으로 대체

from google.colab import drive 
drive.mount('/content/drive/')

file = '/content/drive/My Drive/Colab Notebooks/titanic.csv'

df = pd.read_csv(file)

df2 = df.copy()

mean_age = df2['Age'].mean()
df2['Age'].fillna(mean_age, inplace=True)
df2['Age'].isna().sum()
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# 0

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %% [markdown]
# # 중복데이터 처리

# %%
df = pd.DataFrame({'A':['a','a','b','a','b'],
                   'B':[1,1,1,2,2],
                   'C':[1,1,2,2,2]})
df
# Out:
#    A  B  C
# 0  a  1  1
# 1  a  1  1
# 2  b  1  2
# 3  a  2  2
# 4  b  2  2

# %%
df.duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df['A'].duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# Name: A, dtype: bool

# %%
df.drop_duplicates()
# Out:
#    A  B  C
# 0  a  1  1
# 2  b  1  2
# 3  a  2  2
# 4  b  2  2

# %% [markdown]
# # 실습II
#
# # 2010년부터 10여년간 울릉도 지역의 기온과 바람 세기를 측정한 데이터셋을 이용한 기상데이터 분석 실습

# %% [markdown]
# ## 1.weather.csv 파일을 읽어와서 처음 3행을 출력해보세요.(힌트: 한글 인코딩 encoding='CP949')

# %%
import pandas as pd

path = 'https://github.com/dongupak/DataML/raw/main/csv/' 
weather_file = path + 'weather.csv'

weather = pd.read_csv(weather_file, index_col = 0, encoding='CP949')
print(weather.head(3))
print('weather 데이터의 shape :', weather.shape)
# Out:
#             평균기온  최대풍속  평균풍속
# 일시
# 2010-08-01  28.7   8.3   3.4
# 2010-08-02  25.2   8.7   3.8
# 2010-08-03  22.1   6.3   2.9
# weather 데이터의 shape : (3653, 3)

# %% [markdown]
# ## 2. 평균기온,최대풍속, 평균풍속의 평균과 표준편차를 출력해보세요.

# %%
weather.describe()
# Out:
#               평균기온         최대풍속         평균풍속
# count  3653.000000  3649.000000  3647.000000
# mean     12.942102     7.911099     3.936441
# std       8.538507     3.029862     1.888473
# min      -9.000000     2.000000     0.200000
# 25%       5.400000     5.700000     2.500000
# 50%      13.800000     7.600000     3.600000
# 75%      20.100000     9.700000     5.000000
# max      31.300000    26.000000    14.900000

# %%
print('평균----------------')
print(weather.mean())
print('표준편차----------------')
print(weather.std())
# Out:
# 평균----------------
# 평균기온    12.942102
# 최대풍속     7.911099
# 평균풍속     3.936441
# dtype: float64
# 표준편차----------------
# 평균기온    8.538507
# 최대풍속    3.029862
# 평균풍속    1.888473
# dtype: float64

# %% [markdown]
# ## 3. 다음과 같이 전체 데이터에 대하여 최대풍속과 평균풍속의 최대값을 출력해보세요.

# %%
print('최대풍속의 최대값   ',weather['최대풍속'].max())
print('평균풍속의 최대값   ',weather['평균풍속'].max())
# Out:
# 최대풍속의 최대값    26.0
# 평균풍속의 최대값    14.9

# %% [markdown]
# ## 4.평균풍속의 결측치를 출력하세요. (힌트: isna() )

# %%
missing_data = weather[weather['평균풍속'].isna()]
missing_data
# Out:
#             평균기온  최대풍속  평균풍속
# 일시
# 2012-02-11  -0.7   NaN   NaN
# 2012-02-12   0.4   NaN   NaN
# 2012-02-13   4.0   NaN   NaN
# 2015-03-22  10.1  11.6   NaN
# 2015-04-01   7.3  12.1   NaN
# 2019-04-18  15.7  11.7   NaN

# %% [markdown]
# ## 5. 평균풍속의 결측치를 삭제해보세요.(힌트: dropna())

# %%
weather.dropna(inplace=True)

# %%
weather.isnull().sum()
# Out:
# 평균기온    0
# 최대풍속    0
# 평균풍속    0
# dtype: int64

# %% [markdown]
# ## 6. 평균풍속의 결측치를 평균값으로 채우고 원본데이터를 수정해보세요.(힌트: fillna())

# %%
weather.fillna(weather['평균풍속'].mean(), inplace=True)
print(weather.loc['2012-02-11'])
# Out:
# 평균기온   -0.700000
# 최대풍속    3.936441
# 평균풍속    3.936441
# Name: 2012-02-11, dtype: float64

# %% [markdown]
# ## 7. 2015년 6월 6일의 울릉도 평균 기온과 풍속 정보를 다음과 같이 확이해보세요.

# %%
print(weather.loc['2015-06-06'])
# Out:
# 평균기온    16.6
# 최대풍속     4.4
# 평균풍속     1.9
# Name: 2015-06-06, dtype: float64

# %% [markdown]
# ## 8. 가장 무더웠던 날이 언제이고, 이 날의 평균기온, 평균풍속, 최대풍속을 알아 보라(힌트:
# weather[weather[‘평균기온’] == weather[‘평균기온’].max()]로 데이터 접근하여라).

# %%
weather[weather['평균기온'] == weather['평균기온'].max()]
# Out:
#             평균기온  최대풍속  평균풍속
# 일시
# 2013-08-08  31.3   7.8   4.6

# %% [markdown]
# ## 9. 울릉도의 평균기온은 30도를 넘는 날들을 찾아, 이날의 기상 데이터를 나열해 보세요.

# %%
weather[ weather['평균기온'] > 30]
# Out:
#             평균기온  최대풍속  평균풍속
# 일시
# 2013-08-08  31.3   7.8   4.6
# 2013-08-09  30.6   9.9   6.4
# 2013-08-10  30.6   7.4   3.8
# 2018-07-23  30.5   6.5   1.6
# 2018-08-04  30.3   5.8   3.0

# %% [markdown]
# ## 시계열 자료 분석

# %%
import pandas as pd

# 다양한 형식의 연,월,일 표시 데이터
d_list = ["01/03/2018", "01-03-2018", "2018-01-05", "2018/01/06"]
pd.DatetimeIndex(d_list).year    # 년도 값을 출력함
# Out:
# Int64Index([2018, 2018, 2018, 2018], dtype='int64')

# %%
pd.DatetimeIndex(d_list).month   # 월 값을 출력함
# Out:
# Int64Index([1, 1, 1, 1], dtype='int64')

# %%
pd.DatetimeIndex(d_list).day     # 일 값을 출력함
# Out:
# Int64Index([3, 3, 5, 6], dtype='int64')

# %%
dt_list = ["01,03,2018 11:12:13", "01-03-2018 11:22:13"]
pd.DatetimeIndex(dt_list).hour     # 시 값을 출력함
# Out:
# Int64Index([11, 11], dtype='int64')

# %%
pd.DatetimeIndex(dt_list).minute   # 분 값을 출력함
# Out:
# Int64Index([12, 22], dtype='int64')

# %%
pd.to_datetime(d_list)
# Out:
# DatetimeIndex(['2018-01-03', '2018-01-03', '2018-01-05', '2018-01-06'], dtype='datetime64[ns]', freq=None)

# %%
pd.to_datetime(dt_list)
# Out:
# DatetimeIndex(['2018-01-01 11:12:13', '2018-01-03 11:22:13'], dtype='datetime64[ns]', freq=None)

# %%
pd.DatetimeIndex(dt_list).minute   # 분 값을 출력함
# Out:
# Int64Index([12, 22], dtype='int64')

# %% [markdown]
# # 그룹핑

# %%
weather = pd.read_csv(weather_file, encoding='CP949')
weather['month'] = pd.DatetimeIndex(weather['일시']).month
weather.head()
# Out:
#            일시  평균기온  최대풍속  평균풍속  month
# 0  2010-08-01  28.7   8.3   3.4      8
# 1  2010-08-02  25.2   8.7   3.8      8
# 2  2010-08-03  22.1   6.3   2.9      8
# 3  2010-08-04  25.3   6.6   4.2      8
# 4  2010-08-05  27.2   9.1   5.6      8

# %%
monthly_means = weather.groupby('month').mean()
print(monthly_means)
# Out:
#             평균기온      최대풍속      평균풍속
# month
# 1       1.598387  8.158065  3.757419
# 2       2.136396  8.225357  3.946786
# 3       6.250323  8.871935  4.390291
# 4      11.064667  9.305017  4.622483
# 5      16.564194  8.548710  4.219355
# 6      19.616667  6.945667  3.461000
# 7      23.328387  7.322581  3.877419
# 8      24.748710  6.853226  3.596129
# 9      20.323667  6.896333  3.661667
# 10     15.383871  7.766774  3.961613
# 11      9.889667  8.013333  3.930667
# 12      3.753548  8.045484  3.817097

# %%
monthly_means['평균풍속'] >= 4.0
# Out:
# month
# 1     False
# 2     False
# 3      True
# 4      True
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# Name: 평균풍속, dtype: bool

# %%
monthly_means[ monthly_means['평균풍속'] >= 4.0 ]
# Out:
#             평균기온      최대풍속      평균풍속
# month
# 3       6.250323  8.871935  4.390291
# 4      11.064667  9.305017  4.622483
# 5      16.564194  8.548710  4.219355

# %% [markdown]
# # 데이터 구조 변경

# %%
import pandas as pd
 
df = pd.DataFrame({'상품' : ['시계', '반지', '반지', '목걸이', '팔찌'], 
                   '재질' : ['금', '은', '백금', '금', '은'], 
                   '가격': [500000, 20000, 350000, 300000, 60000]}) 
df
# Out:
#     상품  재질      가격
# 0   시계   금  500000
# 1   반지   은   20000
# 2   반지  백금  350000
# 3  목걸이   금  300000
# 4   팔찌   은   60000

# %%
new_df = df.pivot(index='상품', columns='재질', values='가격', )

# %%
new_df.fillna(value=0)
# Out:
# 재질          금        백금        은
# 상품
# 목걸이  300000.0       0.0      0.0
# 반지        0.0  350000.0  20000.0
# 시계   500000.0       0.0      0.0
# 팔찌        0.0       0.0  60000.0

# %% [markdown]
# # DataFrame 합치기

# %%
#Series + Series

A = pd.Series(['a0','a1','a2','a3'], name ='a')
B = pd.Series(['b0','b1','b2'], name ='b',index=[3,4,5])
C = pd.Series(['c0','c1','c2','c3'],name='c')
print(A, B, C)
# Out:
# 0    a0
# 1    a1
# 2    a2
# 3    a3
# Name: a, dtype: object 3    b0
# 4    b1
# 5    b2
# Name: b, dtype: object 0    c0
# 1    c1
# 2    c2
# 3    c3
# Name: c, dtype: object

# %%
pd.concat([A,B]) #axis = 0 기본
# Out:
# 0    a0
# 1    a1
# 2    a2
# 3    a3
# 3    b0
# 4    b1
# 5    b2
# dtype: object

# %%
type(pd.concat([A,B]))
# Out:
# pandas.core.series.Series

# %%
pd.concat([A,C])
# Out:
# 0    a0
# 1    a1
# 2    a2
# 3    a3
# 0    c0
# 1    c1
# 2    c2
# 3    c3
# dtype: object

# %%
pd.concat([A,C], axis=1)
# Out:
#     a   c
# 0  a0  c0
# 1  a1  c1
# 2  a2  c2
# 3  a3  c3

# %%
pd.concat([A,B], axis=1)
# Out:
#      a    b
# 0   a0  NaN
# 1   a1  NaN
# 2   a2  NaN
# 3   a3   b0
# 4  NaN   b1
# 5  NaN   b2

# %%
type(pd.concat([A,B], axis=1))
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = pd.DataFrame({'a':['a0','a1','a2'],
                    'b':['b0','b1','b2'],
                    'c':['c0','c1','c2']},
                    index=[0,1,2])
df1
# Out:
#     a   b   c
# 0  a0  b0  c0
# 1  a1  b1  c1
# 2  a2  b2  c2

# %%
df2 = pd.DataFrame({'b':['b2','b3','b4'],
                    'c':['c2','c31','c4'],
                    'd':['d2','d3','d4']},
                    index=[1,2,3])
df2
# Out:
#     b    c   d
# 1  b2   c2  d2
# 2  b3  c31  d3
# 3  b4   c4  d4

# %%
pd.concat([df1, df2])
# Out:
#      a   b    c    d
# 0   a0  b0   c0  NaN
# 1   a1  b1   c1  NaN
# 2   a2  b2   c2  NaN
# 1  NaN  b2   c2   d2
# 2  NaN  b3  c31   d3
# 3  NaN  b4   c4   d4

# %%
pd.concat([df1, df2],ignore_index=True)
# Out:
#      a   b    c    d
# 0   a0  b0   c0  NaN
# 1   a1  b1   c1  NaN
# 2   a2  b2   c2  NaN
# 3  NaN  b2   c2   d2
# 4  NaN  b3  c31   d3
# 5  NaN  b4   c4   d4

# %%
pd.concat([df1, df2],axis=1, join ='inner')
# Out:
#     a   b   c   b    c   d
# 1  a1  b1  c1  b2   c2  d2
# 2  a2  b2  c2  b3  c31  d3

# %%
import pandas as pd
df_1 = pd.DataFrame({'A':['a10','a11','a12'],
                     'B':['b10','b11','b12'],
                     'C':['c10','c11','c12']},
                     index=['가','나','다'])
df_2 = pd.DataFrame({'B':['b23','b24','b25'],
                     'C':['c23','c24','c25'],
                     'D':['d23','d24','d25']},
                     index=['다','라','마'])
print(df_1)
print(df_2)
# Out:
#      A    B    C
# 가  a10  b10  c10
# 나  a11  b11  c11
# 다  a12  b12  c12
#      B    C    D
# 다  b23  c23  d23
# 라  b24  c24  d24
# 마  b25  c25  d25

# %%
df_3 = df_1.merge(df_2, how='outer',on='B')
df_3
# Out:
#      A    B  C_x  C_y    D
# 0  a10  b10  c10  NaN  NaN
# 1  a11  b11  c11  NaN  NaN
# 2  a12  b12  c12  NaN  NaN
# 3  NaN  b23  NaN  c23  d23
# 4  NaN  b24  NaN  c24  d24
# 5  NaN  b25  NaN  c25  d25

# %%
df_3 = df_1.merge(df_2, how='outer',on='B',
                  left_index=True, right_index=True)
df_3
# Out:
#      A    B  C_x  C_y    D
# 가  a10  b10  c10  NaN  NaN
# 나  a11  b11  c11  NaN  NaN
# 다  a12  b12  c12  c23  d23
# 라  NaN  b24  NaN  c24  d24
# 마  NaN  b25  NaN  c25  d25

# %% [markdown]
# #실습III

# %% [markdown]
# ## 1. np.random.randint(0, 100, size=5)와 같은 코드를 통해 0에서 100범위의 정수를 5개 생성할 수 있다. 이 숫자들을 다음과 같은 인덱스를 가지는 num_series라는 시리즈의 데이터 값으로 넣어서 출력하여라. 단, 넘파이 난수 생성시 씨드값 85

# %%
import pandas as pd
import numpy as np

np.random.seed(85)
num_series = pd.Series(np.random.randint(0,100, size=5),
                        index=['a', 'b', 'c', 'd', 'e'])
num_series
# Out:
# a    32
# b    13
# c    68
# d    51
# e    13
# dtype: int64

# %% [markdown]
# ### 이 num_series 의 최대값을 출력하세요

# %%
print('num_series의 최대값 :', num_series.max())
# Out:
# num_series의 최대값 : 68

# %% [markdown]
# ### 이 num_series 의 최소값을 출력하세요

# %%
print('num_series의 최소값 :', num_series.min())
# Out:
# num_series의 최소값 : 13

# %% [markdown]
# ### 이 num_series 의 평균값을 출력하세요

# %%
print('num_series의 평균값 :', num_series.mean())
# Out:
# num_series의 평균값 : 35.4

# %% [markdown]
# ## 2.다음과 같은 2개의 데이터프레임 판다스의 DataFrame 클래스를 이용하여 생성하고 이 데이터프레임의 이름을 df_1, df_2로 하세요..

# %%
import pandas as pd

df_1 = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                     'B': ['B0', 'B1', 'B2'],
                     'C': ['C0', 'C1', 'C2'],
                     'D': ['D0', 'D1', 'D2']})
print(df_1)
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2

# %%
df_2 = pd.DataFrame({'B': ['B2', 'B3'],
                     'C': ['C2', 'C3'],
                     'D': ['D2', 'D3'],
                     'E': ['E2', 'E3']})

print(df_2)
# Out:
#     B   C   D   E
# 0  B2  C2  D2  E2
# 1  B3  C3  D3  E3

# %%
df_12_outer = pd.concat([df_1, df_2], join='outer') # union, default
print(df_12_outer)
# Out:
#      A   B   C   D    E
# 0   A0  B0  C0  D0  NaN
# 1   A1  B1  C1  D1  NaN
# 2   A2  B2  C2  D2  NaN
# 0  NaN  B2  C2  D2   E2
# 1  NaN  B3  C3  D3   E3

# %%
df_12_inner = pd.concat([df_1, df_2], join='inner', axis=1)
print(df_12_inner)
# Out:
#     A   B   C   D   B   C   D   E
# 0  A0  B0  C0  D0  B2  C2  D2  E2
# 1  A1  B1  C1  D1  B3  C3  D3  E3
